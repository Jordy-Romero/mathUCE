# %% [markdown]
# #**Clase 5: Función biyectiva y compuesta**
# Como ya vimos en la anterior clase, una función es una regla de correspondencia entre dos conjuntos de tal manera que a cada elemento del primer conjunto le corresponde uno y sólo un elemento del segundo conjunto . Al primer conjunto (el conjunto D) se le da el nombre de dominio.
#
# Una comparación matemática es una relación binaria entre dos conjuntos , que pueden cumplir o no cuatro propiedades: Unicidad de imagen: los elementos del conjunto inicial que tienen imagen tienen una sola imagen.
#
# A continuación, vamos a analizar los tipos de funciones inversa, compuesta, inyectiva, sobreyectiva y biyectiva.
#
# ![Texto alternativo](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhEtYk6ibkLBSlag6vAbCG9DLBTm2aGOkYrGUwvsGOympGG4BS6DULXo_Opqh66MB8KFVDR6c_j6haxMLb_wmXUmM2A8RyFutFGXN9KHqRjm-8a6z78yxq4lU_Tg_JCdEuZ6Rdvz_mAZKhP/s1600/200px-Bijection_svg.png)
#
# ##**Función Inversa**
# Una función inversa es la reflexión de la función original en la recta, por lo que podemos utilizar la recta original y la recta $y = x$ como recta de reflexión.
#
# En general, una función es invertible solo cuando cada valor de entrada tiene un valor de salida único . Es decir, cada valor de salida corresponde exactamente a un valor de entrada. De esa manera, cuando el mapeo se invierte, ¡también es una función!
# $$f:X→Y$$
# $$f^{-1}:Y→X$$
#
# ###**Ejemplo:**
# ![Texto alternativo](https://upload.wikimedia.org/wikipedia/commons/c/c8/Inverse_Function.png)
#
#
# ###**Gráficas de la función inversa**
# A la izquierda, la gráfica de una función lineal, en rojo, y su inversa, en verde. A la derecha, la gráfica de la parte positiva de una parábola, en rojo, y su inversa, en verde. En ambas gráficas y en puntos suspensivos hemos representado la recta $y=x$ respecto a la cual se produce la simetría entre las funciones originales y sus respectivas inversas.
#
# ![Texto alternativo](https://www.fisicalab.com/sites/all/files/contenidos/matematicas/2225_f_inversa/ejemplos_inversas.jpg)
#
# ###**Ejercicio:**
# Digamos que tenemos la funcion
# $$h ( x ) = x^3 + 4$$
# Reemplace h ( x ) con y e intercambia $x$ y $y$:
# $$x = y^3 + 4$$
# Resuelva para $y^3= x – 4$
# $$y=\sqrt[3]{x-4}$$
#
# ###**Gráfico:**
# ![Texto alternativo](https://www.varsitytutors.com/assets/vt-hotmath-legacy/hotmath_help/topics/inverse-functions/inverse%20of%20a%20fn.gif)
#
#
# ##**Función Compuesta**
# En álgebra abstracta, una función compuesta es una función formada por la composición o aplicación sucesiva de otras dos funciones . Para ello, se aplica sobre el argumento la función más próxima al mismo, y al resultado del cálculo anterior se le aplica finalmente la función restante.
# $$A→B→C$$
# $$x→f(x)→g((f(x))$$
#
# ![Texto alternativo](https://www.mat.uson.mx/~jldiaz/WFunciones/Fun-9_archivos/image005.png)
#
# ##**Dominio función compuesta**
# En la ilustración aparecen los dominios y recorridos de $f y g$. Como puedes ver, el recorrido de $f$ no está íntegramente incluido en el dominio de $g$ con lo que el dominio de $g ∘ f$ es un subconjunto de $f$: el de aquellos elementos que tienen imagen en el dominio de $g$.
#
# En la expresión anterior aparece $f-1$. Se trata de la función inversa, que vamos a estudiar en el apartado inmediatamente posterior del tema. De momento te bastará con saber que, de manera complementaria a $f(x)$, que nos permite pasar de un valor del dominio a su imagen (que es un valor del recorrido), la función inversa $f^{-1}(x)$, nos permite pasar de un valor del recorrido a su antiimagen (que es un valor del dominio).
#
# ![Texto alternativo](https://www.fisicalab.com/sites/all/files/contenidos/matematicas/2292_f_compuesta/dominio_composicion_2.jpg)
#
# ##**Propiedades**
# **No conmutativa:**
# Es decir, tal y como habíamos señalado anteriormente, el orden en que aplicamos la composición generalmente condicione el resultado obtenido.
# $$gof \neq fog$$
#
# **Asociativa:**
# Es decir, dadas $3$ funciones cualesquiera, se obtiene igual resultado componiendo la primera $(f)$ y la segunda $(g)$, y componiendo posteriormente el resultado con la tercera $(h)$, que componiendo la segunda $(g)$ y la tercera $(h)$ y componiendo posteriormente la primera $(f)$ con el resultado obtenido.
# $$ho(gof)=(hog)of$$
#
# ##**Ejercicios:**
# 1) Encuentra el valor de $𝑓(𝑔(3))f(g(3))$ si es que tenemos las funciones $𝑓(𝑥)=2𝑥+5f(x)=2x+5$ y $𝑔(𝑥)=𝑥+6g(x)=x+6.$
# ## Resolver el ejercicio paso a paso
#
# Empezamos evaluando $g(3)$. Entonces, tenemos:
#
# $$ g(3) = 3 + 6$$
#
# $$g(3) = 9 $$
#
# Ahora que conocemos el valor de $g(3)$, podemos usarlo en $f(g(3))$:
#
# $$f(g(3)) = f(9)$$
#
# $$f(9) = 2(9) + 5$$
#
# $$f(g(3)) = 23$$
#
# 2) Cálculo de $g(f(-3))$
#
# Dadas las funciones $f(x) = x^2 - 5$ y $g(x) = 2x - 7$, vamos a encontrar el valor de $g(f(-3))$.
#
# ### Paso 1: Evaluar $f(-3)$
#
# $$f(-3) = (-3)^2 - 5$$
# $$f(-3) = 9 - 5$$
# $$f(-3) = 4$$
#
# ### Paso 2: Evaluar $g(f(-3))$
#
# Sabemos que $f(-3) = 4$, entonces evaluamos $ g$:
#
# $$g(f(-3)) = g(4)$$
# $$g(4) = 2(4) - 7 $$
# $$g(4) = 8 - 7 $$
#
# ### Resultado Final
#
# El valor de $g(f(-3))$ es $ 1 $.
#
# ##**Función Inyectiva**
# En matemáticas, una función inyectiva es una función f que asigna elementos distintos de su dominio a elementos distintos; es decir, $x₁ ≠ x₂$ implica $f ≠ f$. En otras palabras, cada elemento del codominio de la función es la imagen de, como máximo, un elemento de su dominio.
#
# ![Texto alternativo](https://funcionmatematica.com/wp-content/uploads/2021/11/FUNCION-INYECTIVA.jpg)
#
# ##**Criterio de la recta horizontal**
# También se puede determinar si una función es inyectiva a través de su representación
# gráfica en el sistema de coordenadas. Se utiliza el criterio de la recta horizontal, el cual,
# consiste en trazar (como dice el nombre), rectas horizontales. Si la recta corta a la gráfica en
# un solo punto, la función es inyectiva, y si corta en más de un punto la función no es
# inyectiva.
#
# ##**Ejercicios:**
# Determinar de manera algebraica si la función es inyectiva
# Otra forma para determinar si una función es inyectiva es de manera algebraica, esto se hace
# verificando si se cumple o no que; $f (x) = f (y), x = y$.
#
# 1) Determina si la función $f(x) = 3 x – 1$ es inyectiva.
# Como:
# $$f (x) = 3x – 1$$
# Entonces:
# $$f (y) = 3y – 1$$
# $$f (x) = f (y)$$
# Reemplazamos:
# $$3x – 1 = 3y – 1$$
# $$3x = 3y$$
# $$x = y$$
# Se cumple la afirmación, ya que si dos imágenes son iguales las preimágenes deben ser iguales,
# entonces la función es inyectiva.
#
# 2)  Determina si la función $f(x) = x^2$ es inyectiva.
# Comprobamos si se cumple que $f (x) = f (y)$:
# $$f (x) = f (y)$$
# $$x^2 = y^2$$
# $$x^2-y^2=0$$
# $$(x + y) (x – y) = 0$$
# Entonces:
#  $$x + y = 0 ; x – y = 0$$
#  $$x = -y ; x = y$$
#  No se cumple la afirmación, ya que, si dos imágenes son iguales, habrá dos preimágenes una
# positiva y otra negativa con la misma imagen. Por ejemplo, si reemplazamos dos elementos del
# dominio $x = 2$ e $y = - 2$, $f (2) = 22 = 4$, y $f (-2) = - 2^2 = 4$, podemos ver que tienen la misma imagen,
# por lo tanto no es una función inyectiva.
#
# ##**Función Sobreyectiva**
# Una función es sobreyectiva cuando todos los elementos del codominio son imagen de al menos
# un elemento del dominio, es decir, el codominio es igual al recorrido.
# En lenguaje algebraico, una función f de A en B es sobreyectiva cuando;
# $$Rec (f) = B$$
# Si se representara una función sobreyectiva, en un diagrama sagital, de una función $f$ de $A$ en $B$,
# veríamos que todos los elementos $B$ tienen al menos una flecha desde el conjunto $A$.
# También se conoce como función epiyectiva.
#
# ##**Ejercicios:**
# 1) Determina si la función $f (x) = x^3$ es sobreyectiva.
#
# ![Texto alternativo](https://www.varsitytutors.com/assets/vt-hotmath-legacy/hotmath_help/topics/cubic-functions/cubic-functions.gif)
#
# Resaltamos el recorrido (imágenes) de la función, para que se vea con más claridad si la
# función es sobreyectiva.
# Entonces, en este caso, el dominio, el codominio y el recorrido son todos los números reales.
# $$Dom (f) = R$$
# $$Codom (f) = R$$
# $$Rec (f) = R$$
#
# Por lo tanto, como el recorrido es igual al codominio es una función sobreyectiva.
#
# 2) Determinar si la función $f: R > R$, donde $f (x) = x2 + 2$ es sobreyectiva
#
# ![Texto alternativo](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTIVyf7ZjDZOWtugoCb5raHfbI3h5QmCyx8tw&s)
#
# También resaltamos el recorrido (imágenes) de la función, para que se vea con más claridad si la
# función es sobreyectiva.
# Entonces, en este caso, el dominio, el codominio son todos los números reales, y el recorrido son
# todos los números reales mayores o iguales a $2$.
# $$Dom (f) = R$$
# $$Codom (f) = R$$
# $$Rec (f) = [2 ; +∞)$$
# Como se puede, el recorrido y el codominio no coinciden, por lo tanto, no es una función
# sobreyectiva.
# Se puede redefinir el codominio de la función $f: R > R$, donde $f (x) = x2 + 2$, de modo que sea
# sobreyectiva.
# En el ejemplo anterior, se ve que el recorrido de la función son todos los números reales mayores
# o iguales a dos. Por lo tanto, si en codominio (conjunto de llegada) fuera igual sería una función
# sobreyectiva, para esto podemos definir la función como:
# $$f: r [2 ; +∞)$$
# Entonces, como se redefinió el codominio para $f (x) = x2 + 2$, y ahora el recorrido es igual al
# codominio, la función es sobreyectiva.
#
# ##**Función Biyectiva**
# Una función es biyectiva cuando es inyectiva y sobreyectiva a la vez, es decir, cuando todas las
# imágenes tienen una sola preimagen y no existen elementos del codominio que no tengan una
# preimagen.
# En lenguaje algebraico, una función f de A en B es biyectiva si se cumple que, siendo $x$ e $y$
# elementos de $A$:
# $$f (x) = f (y)→x = y$$
# $$Rec (f) = B$$
# Si se representa una función biyectiva, en un diagrama sagital, de una función $f$ de $A en B$,
# veríamos que todos los elementos B tienen sólo una flecha desde el conjunto $A$.
#
# ##**Ejemplo de función biyectiva en un diagrama sagital.**
#
# ![Texto alternativo](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Bijection.svg/1200px-Bijection.svg.png)
#
# Entonces, como una función es biyectiva cuando es inyectiva y sobreyectiva a la vez, puedes
# ocupar los métodos que ya se explicaron, y comprobar si se cumple esta condición.
#
# ##**Ejercicios:**
#
# 1) Determina si la función $f: R > R$, donde $f (x) = 2x – 1$ es una función biyectiva.
# Primero verificar si la función es inyectiva, Comprobando si se cumple que $f (x) = f (y)$:
# $$2x – 1 = 2y – 1$$
# $$2x = 2y$$
# $$x = y$$
# Se cumple la afirmación, ya que si dos imágenes son iguales las preimágenes deben ser iguales,
# entonces la función es inyectiva.
# Ahora se verifica si es una función sobreyectiva, grafica de la función:
#
# ![Texto alternativo](https://homework.study.com/cimages/multimages/16/lineargraph2891049335614484006.jpg)
#
# **Se puede ver que:**
# - El dominio o conjunto inicial son todos los números reales.
# - El codominio o conjunto final son todos los números reales.
# - El recorrido (imagen) son también todos los números reales.
# Entonces, el codominio y recorrido de y coinciden, por lo tanto es una función sobreyectiva.
# Ahora como la función es inyectiva y sobreyectiva a la vez, es una función biyectiva.
#
# ##**Códigos de Python**
# ###**Función Inversa**
# ```python
# # Definición de la función original f(x)
# def f(x):
#     return 2*x + 3
#
# # Función para encontrar la función inversa f^{-1}(y)
# def f_inversa(y):
#     return (y - 3) / 2
#
# # Ejemplo de uso
# x = 5
# print(f"f({x}) =", f(x))
#
# # Encontrar f^{-1}(y) para y = 13
# y = 13
# print(f"f_inversa({y}) =", f_inversa(y))
# ```
# ###**Función Compuesta**
# ```python
# # Definición de las funciones f(x) y g(x)
# def f(x):
#     return 2*x + 3
#
# def g(x):
#     return x**2
#
# # Definición de la función compuesta (f ∘ g)(x)
# def funcion_compuesta(x):
#     return f(g(x))
#
# # Ejemplo de uso
# x = 2
# resultado = funcion_compuesta(x)
# print(f"El resultado de (f ∘ g)({x}) es:", resultado)
# ```
# ###**Función Inyectiva**
# ```python
# # Definición de la función f(x) = 2x
# def f(x):
#     return 2 * x
#
# # Verificar si la función es inyectiva
# def es_inyectiva(funcion):
#     valores = set()
#     for x in range(-100, 101):  # Comprobar en un rango amplio de números enteros
#         valor = funcion(x)
#         if valor in valores:  # Si ya se ha asignado este valor, la función no es inyectiva
#             return False
#         valores.add(valor)
#     return True
#
# # Comprobar si f(x) = 2x es inyectiva
# if es_inyectiva(f):
#     print("La función f(x) = 2x es una función inyectiva.")
# else:
#     print("La función f(x) = 2x NO es una función inyectiva.")
# ```
# ###**Función Biyectiva**
# ```python
# # Definición de la función f(x) = 2x + 1
# def f(x):
#     return 2 * x + 1
#
# # Verificar si la función es biyectiva
# def es_biyectiva(funcion):
#     valores = set()
#     preimagenes = set()
#     for x in range(-100, 101):  # Comprobar en un rango amplio de números enteros
#         valor = funcion(x)
#         if valor in valores:  # Si ya se ha asignado este valor, la función no es inyectiva
#             return False
#         valores.add(valor)
#         preimagenes.add(x)
#     # Verificar si todas las imágenes tienen preimagen
# ```
# ###**Función Sobreyectiva**
# ```python
# # Definición de la función f(x) = x^2
# def f(x):
#     return x**2
#
# # Verificar si la función es sobreyectiva
# def es_sobreyectiva(funcion):
#     valores = set()
#     for x in range(-100, 101):  # Comprobar en un rango amplio de números enteros
#         valor = funcion(x)
#         valores.add(valor)
#     # Verificar si todos los valores en el codominio están en valores
#     for y in range(0, 101):  # Comprobar solo valores positivos de y por ser x^2
#         if y not in valores:
#             return False
#     return True
#
# # Comprobar si f(x) = x^2 es sobreyectiva
# if es_sobreyectiva(f):
#     print("La función f(x) = x^2 es una función sobreyectiva.")
# else:
#     print("La función f(x) = x^2 NO es una función sobreyectiva.")
# ```
