# %% [markdown]
# # **Cardinalidad y Tipos de Funciones: Inyectivas, Sobreyectivas y Biyectivas** ☝🤓
#
# En la clase anterior, cometimos un error en la formulación de la proposición QQQ. La proposición dada fue:
#
#
# ![imagen1.png](data:image/png;base64,...)
#
#
#
#
#
# Inicialmente se marcó como falsa, pero esto es incorrecto. La proposición es en realidad verdadera. La corrección correcta sería:
#
# ![imagen2.png](data:image/png;base64,...)
#
#
# Al analizar esto, notamos que la proposición original:
#
#
# ![imagen3.png](data:image/png;base64,...)
#
#
# es verdadera para todos los números naturales n, ya que, para cualquier n en los naturales, podemos encontrar un k tal que k≤n Por ejemplo, para n=0, k=0 es una solución válida.
# Sin embargo, al cambiar el signo a estrictamente menor:
#
#
#
# ![imagen4.png](data:image/png;base64,...)
#
# encontramos que
#
# para **n=0**, no existe un **k∈N** que cumpla **k<0**
#
#
# Por lo tanto, esta proposición es falsa debido a este contraejemplo.
#
#
# **Proposición y su Negación**
#
# La negación de la proposición original es:
#
# ![imagen5.png](data:image/png;base64,...)
#
#
# Esto significa que existe al menos un número natural n para el cual no hay ningún k en los naturales que sea menor o igual a n. Esta proposición se traduce a:
#
# ![imagen6.png](data:image/png;base64,...)
#
#
# Este **n** es el número cero, ya que para cualquier **k∈N**, el número cero es menor o igual que **k**. De este modo, la proposición Q es verdadera y su negación ¬Q es falsa.
#
#
# **Equivalencias de Proposiciones Lógicas**
#
#
# Para la proposición: **P→Q**
#
#
# **P→Q≡¬P∨QP**
#
#
#
# La negación de esta proposición sería:
#
#
#
# **¬(P→Q) ≡¬(¬P∨Q) ≡P∧¬Q**
#
#
#
# Otra forma de ver esto es usando el contrarrecíproco:
#
#
# **P→Q≡¬Q→¬P**
#
#
# De manera similar, tenemos:
#
#
# **¬(P→Q)≡P∧¬Q**
#
#
# **Distribución de Valores de Verdad**
#
#
# Al considerar las proposiciones con sus valores de verdad, podemos usar una tabla de verdad para mostrar las equivalencias y negaciones.
#
#
# **1.	Tabla de Verdad para P→ Q:**
#
# ![Captura de pantalla 2024-07-07 220829.png](data:image/png;base64,...)
#
#
# **2.	Tabla de Verdad para ¬P∨Q:**
#
#
# Como se observa, las dos tablas tienen los mismos valores de verdad, confirmando la equivalencia.
#
#
# ![Captura de pantalla 2024-07-07 221001.png](data:image/png;base64,...)
#
#
# **3.	Negación de P→Q:**
#
# ![Captura de pantalla 2024-07-07 221039.png](data:image/png;base64,...)
#
#
#
# **Aplicación en Ejemplos**
# Para mostrar la equivalencia y negación en ejemplos concretos, considera:
#
#
# **P:**"Si llueve, entonces la calle estaˊ mojada."
#
#
#  *Q:*"La calle estaˊ mojada
#
#
# La proposición **P→Q** se puede reformular como **¬P∨Q**
#
#
# **¬P:** "No llueve."
#
#
# *¬P∨Q:* "No llueve o la calle está mojada."
#
#
# La negación sería:
#
#
# **¬(P→Q) ≡P∧¬Q**
#
#
# **P∧¬Q:** "Llueve y la calle no está mojada.":
#
#
# Esta es la única situación en la que **P→Q** es falsa.
#
#
#
# **INSUMOS PARA DEMOSTRACION**
#
#
# ![Captura de pantalla 2024-07-07 213412.png](data:image/png;base64,...)
#
#
# ![Captura de pantalla 2024-07-07 213418.png](data:image/png;base64,...)
#
#
#
# ![Captura de pantalla 2024-07-07 213425.png](data:image/png;base64,...)
#
#
# ![Captura de pantalla 2024-07-07 213431.png](data:image/png;base64,...)
#
# Donde:
#
# •	El No P es verdaderov
#
#
# •	Si tenemos que Q es verdadero y P falso, si ambas son falsas el resultado es falso y si ambas son verdaderas el resultado es verdadero.
#
#
# •	Cuando la premisa es falsa, la implicación es siempre verdadera.
#
#
# •	Cuando la premisa se cumple, si es que el resultado es verdadero, la implicación es verdadera.
#
#
# •	Si la premisa se cumple, pero el resultado no, la implicacion es falsa.
#
#
# •	Las tres son formas equivalentes para la P entonces Q.
#
#
#
# ![Captura de pantalla 2024-07-07 215423.png](data:image/png;base64,...)
#
#
# •	Aquí tenemos un tipo de intervalo abierto n a n + 1 que no incluye los dos bordes y tenemos su unión infinita, para todos los N.
#
#
#
#
# •	N:  (Naturales)
#
#
# •	N X N: tiene la misma propiedad que los naturales, es un conjunto.
#
#
# •	Z: Podemos hacer un conteo saltado.
#
#
# •	Q: (Racionales) son los números que se pueden expresar como el cociente de dos enteros, con el denominador diferente de cero.
#
#
# •	Z X Z: Producto cartesiano de los números enteros.
#
#
# •	R: Conjunto de los números reales.
#
#
# •	R sin N: Conjunto de los reales, excluyendo a los naturales.
#
#
# •	C: Conjunto de los números complejos.
#
#
# •	P(R): Conjunto potencia de los números reales.
#
#
#
#
# **El Cardinal de los racionales y los naturales son numerables**
#
#
# **Q ⊆ N X N**
#
#
# La representación de **(Q)** como pares ordenados, si **(Q)** está contenido en **N X N** entonces el cardinal de **(Q)** lógicamente tiene que ser en relación al cardinal de **N x N**, si Q está contenido en **N X N**, el cardinal tiene que ser menor al cardinal de **N X N**, y el cardinal de
# **N X N**, entonces el cardinal de **(Q)** son numerables.
#
#
# **Q ≤ (N X N)**
#
# **N X N** es el conjunto de pares ordenados **(a,b)** tales que a es elemento de **N y B** es elemento de , es un producto cartesiano.
# **N x N =** {(a, b): a E N, b E N}
# **Z X Z** es igual al conjunto de pares ordenados
# **Z X Z =**{(a,b): a E Z , b E Z }
# Q expresado como pares ordenados estaría contenido en **Z X Z**, por lo tanto el cardinal de **( Q )** es menor o igual al cardinal de **( Z x X Z )** esto es igual al cardinal de **( z).**
#
# **Q ⊆ Z X Z**
#
# **(Q) ≤ ( z x z) =** (z)
#
#
# **Números reales**
#
#
# Si le quitamos primero los naturales después los enteros relativos, después los racionales, si le quitamos los racionales, se quedan los irracionales.
# -Si **(Q)** <es un conjunto numerable, pero R es un conjunto no numerable entonces la parte no numerable de R sigue presente.
# **R/Q =** Irracionales -> no numerables π, e, √5 :: P(R)
#
#
# **1.	Inyectividad (Función Inyectiva):**
#
# **•**Una función f: A→Bf: A \ Bf:A→B es inyectiva si para cada elemento en el conjunto de llegada (codominio) BBB, existe a lo sumo un elemento en el conjunto de partida (dominio) AAA que es mapeado a ese elemento.
#
#
# **•**Formalmente, f es inyectiva si f(x1)= f(x2) f(x_1) = f(x_2)f(x1)=f(x2) implica x1=x2x_1 = x_2x1=x2 para todo x1,x2∈Ax_1, x_2 \in Ax1,x2∈A.
#
#
# **•**En otras palabras, dos elementos distintos en el dominio no pueden tener la misma imagen en el codominio.
#
#
# **Ejemplo:** La función f(x)=x2f(x) = x^2f(x)=x2 no es inyectiva en R/{R}R porque, por ejemplo, f(2) = f(−2)=4f(2) = f(-2) = 4f(2)=f(−2)=4.
#
#
# **2.	Sobreyectividad (Función Sobreyectiva):**
#
# **•**	Una función f: A→Bf: A \rightarrow Bf: A→B es sobreyectiva si cada elemento en el conjunto de llegada BBB tiene al menos un elemento en el conjunto de partida AAA que es mapeado a él.
#
#
# **•**	Formalmente, f es sobreyectiva si para todo y∈By \in By∈B, existe al menos un x∈Ax \in Ax∈A tal que f(x)=yf(x) = yf(x)=y.
#
#
# **•**	En términos simples, la función cubre (o alcanza) todos los elementos del codominio.
#
#
# **Ejemplo:** La función f(x) = exf(x) = e^xf(x)=ex, donde f: R→R+f: \{R} \rightarrow \{R}^+f:R→R+, es sobreyectiva porque cada número positivo en R+\{R}^+R+ tiene un preimagen en R/{R}R.
#
#
# **3.	Biyectividad (Función Biyectiva):**
#
#
# **•**	Una función f:A→Bf: A \rightarrow Bf:A→B es biyectiva si es tanto inyectiva como sobreyectiva.
#
#
# **•**	Es decir, cada elemento del conjunto de llegada BBB tiene exactamente un elemento correspondiente en el conjunto de partida AAA, y cada elemento en BBB es mapeado por exactamente un elemento en AAA.
#
#
# **•**	En términos simples, una función es biyectiva si es una correspondencia uno a uno y sobre entre AAA y BBB.
#
#
# **Ejemplo:** La función f(x)=2x+1f(x) = 2x + 1f(x)=2x+1 donde f:R→Rf: \{R} \rightarrow \{R}f:R→R es biyectiva porque es tanto inyectiva (cada valor de xxx tiene una única imagen) como sobreyectiva (cada número real es alcanzado por algún xxx).
#
#
# Para entenderlo de mejor manera.
#
# **•	Inyectiva:** Cada elemento del dominio se une a un único elemento del codominio.
#
#
# **•	Sobreyectiva:** Todos los elementos del codominio son alcanzados por al menos un elemento del dominio.
#
#
# **•	Biyectiva:** Es inyectiva y sobreyectiva al mismo tiempo.
#
# **Ejemplo 1**
#
#
#
# **Inyectividad**
#
# Una función f: A→Bf: es inyectiva (o uno a uno) si y solo si, para cada par de elementos distintos x1, x2 en el dominio de A, sus imágenes bajo f son distintas en el codominio B. En otras palabras, f(x1) =f(x2) f(x1) = f(x2) f(x1) = f(x2) implica que         x1= x2.
#
#
# **Ejemplo de función inyectiva:**
#
#  **La función f: R→R(f) definida por f (x)=2x+3f(x) = 2x + 3f(x)=2x+3.**
#
#
# **•**	Para verificar la inyectividad, asumimos que f(x1) =f(x2) f(x_1) = f(x_2) f(x1) =f(x2).
#
#
# **•**	Entonces, 2x1+3=2x2+32x_1 + 3 = 2x_2 + 32x1+3=2x2+3.
#
#
# **•**	Restando 3 de ambos lados: 2x1=2x22x_1 = 2x_22x1=2x2.
#
#
# **•**	Dividiendo por 2: x1=x2x_1 = x_2x1=x2.
#
#
# Como f(x1) =f(x2) f(x_1) = f(x_2) f(x1) =f(x2) implica que x1=x2x_1 = x_2x1=x2, la función f(x)=2x+3f(x) = 2x + 3f(x)=2x+3 es inyectiva.
#
#
# **Ejemplo de función no inyectiva:**
#
#
# **Consideremos la función g: definida por g(x)=x2g(x) = x^2g(x)=x2.**
#
#
# **•**Tomemos x1=2x_1 = 2x1=2 y x2=−2x_2 = -2x2=−2.
#
#
# **•**	Entonces, g (2) =4g (2) = 4g (2) =4 y g (−2) =4g (-2) = 4g (−2) =4.
# Aquí, g(x1) =g(x2) g(x_1) = g(x_2) g(x1) =g(x2) pero x1≠x2 x1 _2x1^=x2.
# Por lo tanto, g(x)=x2g(x) = x^2g(x)=x2 no es inyectiva.
#
#
# **Sobreyectividad**
#
#
# **Una función f: A→Bf: es sobreyectiva si y solo si, para cada elemento y en el codominio BBB, existe al menos un elemento x en el dominio A tal que f(x)=yf(x) = yf(x)=y. En otras palabras, la imagen de f cubre todo el codominio B.**
#
#
# **Ejemplo de función sobreyectiva:**
#
#
# **Consideremos la función h: R→R definida por h(x)=x3h(x) = x^3h(x)=x3.**
#
#
# **•**	Para cada y en {R}R, queremos encontrar un x en {R}R tal que h(x)=yh(x) = yh(x)=y.
#
#
# **•**	Tomemos x=y3x = {y}x=3y.
#
#
# **•**	Entonces, h(y3) =(y3)3=y = {y}) ^3 = yh(3y) =(3y)3=y.
# Como para cada y en {R}R existe un x en {R}R tal que h(x)=yh(x) = yh(x)=y, la función h(x)=x3h(x) = x^3h(x)=x3 es sobreyectiva.
#
#
# **Ejemplo de función no sobreyectiva:**
#
#
# **Consideremos la función k: R→R definida por k(x)=exk(x) = e^xk(x)=ex.**
#
#
# **•**	Queremos encontrar un x en {R}R tal que k(x)=−1k(x) = -1k(x)=−1.
#
#
# **•**Sin embargo, exe^xex nunca toma valores negativos para ningún x en {R}R.
# Por lo tanto, no todos los elementos de{R}R (el codominio) tienen una preimagen en el dominio {R}R, y k(x)=exk(x) = e^xk(x)=ex no es sobreyectiva.
#
#
# **Biyección**
#
#
# **Una función f: A→Bf: es biyectiva si es tanto inyectiva como sobreyectiva. Esto significa que f establece una correspondencia uno a uno y sobre entre los elementos de A y B.**
#
#
# **Ejemplo de función biyectiva:**
#
#
# **Consideremos la función l: R→Rl: definida por l(x)=2x+3l(x) = 2x + 3l(x)=2x+3.**
#
#
# **•**	Como vimos antes, esta función es inyectiva.
#
#
# **•** Para verificar la sobreyectividad, tomemos cualquier y en{R}R y resolvamos l(x)=yl(x) = yl(x)=y:
#
#
# **•**	2x+3=y2x + 3 = y2x+3=y
#
# **•**	2x=y−32x = y - 32x=
#
# **•**	x=y−32x = \ {y - 3}{2}x=2y−3
#
# Para cada y en {R}R, existe un x en {R}R tal que l(x)=yl(x) = yl(x)=y. Así, la función l(x)=2x+3l(x) = 2x + 3l(x)=2x+3 es sobreyectiva.
# Como es tanto inyectiva como sobreyectiva, la función l(x)=2x+3l(x) = 2x + 3l(x)=2x+3 es biyectiva.
#
#
# **1. Función Lineal (inyectiva y sobreyectiva)**
#
#
# **Ejemplo:** f(x)=xf(x) = xf(x)=x
#
# Puntos para graficar:
#
# **•**	(−2,−2)
#
# **•**	(−1,−1)
#
# **•**	(0,0)
#
# **•**	(1,1)
#
# **•**	(2,2)
#
#
#
#
#
# **2. Parábola (no inyectiva)**
#
#
# **Ejemplo:** f(x)=x2f(x) = x^2f(x)=x2
# Puntos para graficar:
#
#
# **•**	(−2,4)
#
# **•**	(−1,1)
#
# **•**	(0,0)
#
# **•**	(1,1)
#
# **•**	(2,4)
#
# **Ejemplo:**
#
# ![Imagen1 ejemplo 3.png](data:image/png;base64,...)
#
# ![Imagen2 ejemplo 4.png](data:image/png;base64,...)
#
# ![Imagen3 ejemplo 5.png](data:image/png;base64,...)
#
# **LINK PREGUNTAS QUIZZIZ**  🕵
#
# https://quizizz.com/join/pre-game/running/U2FsdGVkX1%252BVPdVVT8%252FP%252FcKbjPElboykTRbZOqzZd1rm8yRv9xXVQcKy9oiUrPXFkWgUAOV%252FeyY4NxGlBsEZh%252FNaPD7RstxsXm92ITOyQrc%253D/start
#
#
#
#
# ## Referencias y Licencias
#
# Este trabajo utiliza material del curso "Matemáticas y Programación para Ciencias Sociales" de FLACSO Ecuador.
#
# Pérez, F. (2024). Matemáticas y Programación para Ciencias Sociales. FLACSO Ecuador.
# - Repositorio GitHub: https://github.com/franperezec/math (Licencia MIT)
# - Canal de YouTube: https://www.youtube.com/@FranciscoPerezMatematicas (CC BY 4.0)
#
# Al utilizar este material, acepto cumplir con los términos de las licencias MIT y Creative Commons BY 4.0 respectivamente.
#
# Para más detalles sobre las licencias o usos adicionales, consultar:
# - Licencia MIT: https://opensource.org/licenses/MIT
# - CC BY 4.0: https://creativecommons.org/licenses/by/4.0/deed.es
# -------------
