# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-Romero/mathUCE/blob/main/Tutor%C3%ADa_Grupo1_Jordy%20Romero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * FUNDAMENTOS MATEMÁTICOS: DE LA LÓGICA A LOS ESPACIOS MÉTRICOS | TUTORÍA CLASE 1-10 * 💪🙏
#
# GRUPO 1
#
# Coordinador: Roberth Bautista
#
# • Editora del Notebook: Noelia Zhingre
# y Erika Tocte
#
# • Parte 1: Gema Ante y Jennifer Muso
#
# • Parte 2: Erika Tocte y Noelia Zhingre
#
# • Preguntas: Renny Carvajal
#
#
#
#
#
# Objetivo:
# Esta clase revisa conceptos básicos de lógica proposicional y teoría de conjuntos, preparando a los estudiantes para el examen final.
#
# **Lógica Proposición** ✨
#
# ---
# \
#
# ![image.png](data:image/png;base64,...)
# - Implicación (p → q): Es falsa solo cuando la premisa (p) es verdadera y la conclusión (q) es falsa.
# - Equivalencias: Se revisan equivalencias entre la implicación y otras expresiones:
# - p → q ≡ ¬p ∨ q
# - p → q ≡ ¬q → ¬p
# - Doble Implicación (p ↔ q): Se cumple cuando ambas implicaciones (p → q) y (q → p) son verdaderas.
# - p ↔ q ≡ (¬p ∨ q) ∧ (¬q ∨ p)
# - Teoría de Conjuntos:
# - Descripción Formal de un Conjunto: Se utiliza la notación  {x ∈ E | P(x)} , donde:
# - E: Espacio ambiente (universo).
# - P(x): Propiedad que cumplen los elementos del conjunto.
# - Intervalos: Se revisan intervalos como conjuntos de números reales.
# Ejercicios:
# 1. Negar Proposiciones:
# - Proposición: Para todo n ∈ ℕ, existe un k ∈ ℕ tal que k > n.
# - Negación: Existe un n ∈ ℕ tal que para todo k ∈ ℕ, k ≤ n.
# 2. Equivalencias Lógicas:
# - Demuestra la equivalencia: (p ↔ q) ≡ (¬p ∨ q) ∧ (¬q ∨ p).
# - Simplifica la expresión: (¬p ∨ q) ∧ (¬q ∨ p).
# 3. Descripción Formal de Conjuntos:
# - Describe formalmente el conjunto {x ∈ ℝ | x ∈ [n, n+1]}.
# - Describe formalmente el conjunto de números reales mayores que 5.
# Ejemplos de la Clase de Conjuntos y Lógica Proposicional
#
#
# 1. Negar Proposiciones:
# - Proposición: Para todo n ∈ ℕ, existe un k ∈ ℕ tal que k > n.
# - Explicación: Esta proposición afirma que para cualquier número natural n, siempre existe otro número natural k que es mayor que n. Esto es cierto porque podemos tomar k = n + 1.
# - Negación: Existe un n ∈ ℕ tal que para todo k ∈ ℕ, k ≤ n.
# - Explicación: La negación afirma que existe un número natural n para el cual ningún número natural k es mayor que n. Esto es falso, ya que siempre podemos encontrar un número mayor que n.
# 2. Equivalencias Lógicas:
# - Demuestra la equivalencia: (p ↔ q) ≡ (¬p ∨ q) ∧ (¬q ∨ p).
# - Tabla de Verdad:
# p q ¬p ¬q p ↔ q ¬p ∨ q ¬q ∨ p (¬p ∨ q) ∧ (¬q ∨ p)
# - Conclusión: Como las columnas de (p ↔ q) y (¬p ∨ q) ∧ (¬q ∨ p) son idénticas, se demuestra que ambas expresiones son equivalentes.
# - Simplifica la expresión: (¬p ∨ q) ∧ (¬q ∨ p).
# - Ley Distributiva: Podemos aplicar la ley distributiva para simplificar la expresión:
# - (¬p ∨ q) ∧ (¬q ∨ p) ≡ (¬p ∧ ¬q) ∨ (¬p ∧ p) ∨ (q ∧ ¬q) ∨ (q ∧ p)
# - Simplificación: Sabemos que (¬p ∧ p) y (q ∧ ¬q) son siempre falsas. Por lo tanto, la expresión se simplifica a:
# - (¬p ∧ ¬q) ∨ (q ∧ p)
# 3. Descripción Formal de Conjuntos:
# - Describe formalmente el conjunto {x ∈ ℝ | x ∈ [n, n+1]}.
# - Explicación: Este conjunto representa todos los números reales x que están dentro del intervalo cerrado [n, n+1], donde n es un número real.
# - Descripción Formal: {x ∈ ℝ | n ≤ x ≤ n+1}
# - Describe formalmente el conjunto de números reales mayores que 5.
# - Explicación: Este conjunto contiene todos los números reales que son mayores que 5.
# - Descripción Formal: {x ∈ ℝ | x > 5}

# %% [markdown]
# # Ejercicio Python 🔥

# %%
import pandas as pd

# Definir las proposiciones
def implication(p, q):
    return not p or q

# Generar la tabla de verdad
def truth_table():
    values = []
    for p in [True, False]:
        for q in [True, False]:
            values.append([p, q, implication(p, q)])
    return pd.DataFrame(values, columns=['p', 'q', 'p → q'])

# Mostrar la tabla de verdad
df = truth_table()
print(df)
# Out:
#        p      q  p → q
# 0   True   True   True
# 1   True  False  False
# 2  False   True   True
# 3  False  False   True

# %% [markdown]
# ### Explicación del Código
# 1.	Definir la Implicación: La función implication calcula p→qp
# (si p entonces q).
# 2.	Generar la Tabla de Verdad: La función truth_table genera todas las combinaciones posibles de p y q, y usa la función de implicación para calcular los resultados.
# 3.	Mostrar la Tabla: Utiliza pandas para presentar la tabla de verdad en formato tabular.

# %% [markdown]
# # Intervalos en Teoría de Conjuntos 🙏
#
# ###Intervalos cerrados
#
# Se refiere a un conjunto de números reales que incluye todos los números entre dos valores dados, y también incluye esos valores extremos.
# Se denota generalmente como [a,b], donde a y b son los extremos del intervalo. Esto significa que todos los números x tales que a ≤ a≤b están incluidos en el intervalo.
#
# ### Notación:
# •	Intervalo cerrado: [a,b]
# •	Intervalo abierto: (a,b)
# •	Intervalo semiabierto o semicerrado:
# [a,b): Incluye a pero no b
# (a,b]: Incluye b pero no a
# Propiedades:
#  Los intervalos cerrados incluyen sus puntos extremos.
# Son útiles en análisis matemático y en la teoría de conjuntos para definir conjuntos con límites específicos.
#
#
#
# ### Notación:
# •	Intervalo abierto:(a, b)
# •	Intervalo cerrado: [a, b]
# •	Intervalo semiabierto o encerrado:
# [a, b]: Incluye a, pero no b
# (a, b]: Incluye b, pero no a
# Propiedades:
# Los intervalos abiertos no incluyen sus puntos extremos.
# Son útiles en análisis matemático y en la teoría de conjuntos para definir conjuntos sin incluir límites específicos.
# ]n, n+1[={XEℝ:n<x<n+1}
#
# ### Enteros relativos
# Este conjunto se denota comúnmente como Z que proviene del alemán "Zahlen", que significa "números".
# Z= {…,−3,−2,−1,0,1,2,3,…}
# • Incluyen enteros positivos:1,2, 3,…..
# • Incluyen enteros negativos:-1,-2,-4,…….
# • Incluyen el cero:0
# Propiedades:
# Cerradura: La suma y el producto de dos enteros siempre resultan en otro entero. Por ejemplo:
# 2+3=5 y (−2)×3=−6(-2) \times 3 = -6(−2)×3=−6
#
#
# Asociatividad: La suma y el producto de enteros son asociativos. Por ejemplo:
# (2+3)+4=2+(3+4)(2 + 3) + 4 = 2 + (3 + 4)(2+3)+4=2+(3+4)
#
# Conmutatividad: La suma y el producto de enteros son conmutativos. Por ejemplo:
# 2+3=3+22 + 3 = 3 + 2
#
# Elemento neutro: El cero es el elemento neutro aditivo (a+0=a) y el uno es el elemento neutro multiplicativo (a×1=a)
#
# Elemento inverso: Para cada entero a, existe un entero –a tal que a+(−a) =0.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Notación:
# •	Intervalo abierto:(a, b)
# •	Intervalo cerrado: [a, b]
# •	Intervalo semiabierto o encerrado:
# [a, b]: Incluye a, pero no b
# (a, b]: Incluye b, pero no a
# Propiedades:
# Los intervalos abiertos no incluyen sus puntos extremos.
# Son útiles en análisis matemático y en la teoría de conjuntos para definir conjuntos sin incluir límites específicos.
# ]n, n+1[={XEℝ:n<x<n+1}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Enteros relativos
#
# Este conjunto se denota comúnmente como Z que proviene del alemán "Zahlen", que significa "números".
#
#
#
# Z= {…,−3,−2,−1,0,1,2,3,…}
# • Incluyen enteros positivos:1,2, 3,…..
# • Incluyen enteros negativos:-1,-2,-4,…….
# • Incluyen el cero:0
#
#
# Propiedades:
# Cerradura: La suma y el producto de dos enteros siempre resultan en otro entero. Por ejemplo:
# 2+3=5 y (−2)×3=−6(-2) \times 3 = -6(−2)×3=−6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Asociatividad: La suma y el producto de enteros son asociativos.
#
# ![image.png](data:image/png;base64,...)
#
#
# Por ejemplo:
# (2+3)+4=2+(3+4)(2 + 3) + 4 = 2 + (3 + 4)(2+3)+4=2+(3+4)
#
# Conmutatividad: La suma y el producto de enteros son conmutativos. Por ejemplo:
# 2+3=3+22 + 3 = 3 + 2
#
# Elemento neutro: El cero es el elemento neutro aditivo (a+0=a) y el uno es el elemento neutro multiplicativo (a×1=a)

# %% [markdown]
# **Conmutatividad**
#
# La suma y el producto de enteros son conmutativos. Por ejemplo:
# 2+3=3+22 + 3 = 3 + 2
#
# **Elemento neutro**
#
#  El cero es el elemento neutro aditivo (a+0=a) y el uno es el elemento neutro multiplicativo (a×1=a)
#
# **Elemento inverso**
#
#   Para cada entero a, existe un entero –a tal que a+(−a) =0.
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.	Intervalo Cerrado [a,b][a, b][a,b]:
# o	Incluye los extremos aaa y bbb.
# o	Ejemplo: [1,3][1, 3][1,3] incluye 1, 3 y todos los números entre ellos.
# 2.	Intervalo Abierto (a,b)(a, b)(a,b):
# o	Excluye los extremos aaa y bbb.
# o	Ejemplo: (1,3)(1, 3)(1,3) incluye todos los números entre 1 y 3, pero no 1 ni 3.
# 3.	Intervalo Semi-Abierto:
# o	Cerrado por un extremo: [a,b)[a, b)[a,b) incluye aaa pero excluye bbb.
# 	Ejemplo: [1,3)[1, 3)[1,3) incluye 1 pero no 3.
# o	Abierto por un extremo: (a,b](a, b](a,b] excluye a| pero incluye b.
# 	Ejemplo: (1,3](1, 3](1,3] incluye 3 pero no 1.
# Unión de Conjuntos
# •	La unión de conjuntos incluye todos los elementos que están en al menos uno de los conjuntos.
# •	Ejemplo: La unión de [1,2][1, 2][1,2] y [2,3][2, 3][2,3] es [1,3][1, 3][1,3].

# %% [markdown]
# # Ejercicio en Python ❗
# Vamos a calcular la unión de intervalos con extremos abiertos y cerrados.

# %%
def unir_intervalos(intervalos):
    # Ordenar intervalos por el inicio
    intervalos_ordenados = sorted(intervalos)
    unificados = []
    inicio_actual, fin_actual = intervalos_ordenados[0]

    for inicio, fin in intervalos_ordenados[1:]:
        if inicio <= fin_actual:  # Hay solapamiento
            fin_actual = max(fin_actual, fin)
        else:
            unificados.append((inicio_actual, fin_actual))
            inicio_actual, fin_actual = inicio, fin

    unificados.append((inicio_actual, fin_actual))
    return unificados

# Definir intervalos
intervalos = [(1, 2), (2, 3), (5, 6), (4, 5)]

# Unir los intervalos
intervalos_unidos = unir_intervalos(intervalos)

# Mostrar los intervalos unidos
print("Intervalos unidos:")
for intervalo in intervalos_unidos:
    print(f"[{intervalo[0]}, {intervalo[1]}]")
# Out:
# Intervalos unidos:
# [1, 3]
# [4, 6]

# %% [markdown]
# Explicación del Código
# 1.	Definir Intervalos: Los intervalos están representados como tuplas, (1,2) (1, 2) (1,2) o (2,3) (2, 3)(2,3).
# 2.	Unir Intervalos: La función unir intervalos ordena los intervalos y combina los solapados en intervalos no solapados.
# 3.	Mostrar Resultados: Imprime los intervalos resultantes
#
# ### Unión de una Familia de Conjuntos:
# La unión de una familia de conjuntos {An}n∈I\{A_n\}_{n \in I}{An}n∈I es el conjunto de todos los elementos que están en al menos uno de los conjuntos AnA_nAn.
# o	Formalmente: ⋃n∈IAn={x∣∃n∈I tal que x∈An}\bigcup_{n \in I} A_n = \{ x \mid \exists n \in I \text{ tal que } x \in A_n \}⋃n∈IAn={x∣∃n∈I tal que x∈An}
# 2.	Complemento de una Unión:
# o	El complemento de la unión de una familia de conjuntos es el conjunto de todos los elementos que no están en la unión.
# o	Formalmente: (⋃n∈IAn)c=⋂n∈IAnc\left(\bigcup_{n \in I} A_n\right)^c = \bigcap_{n \in I} A_n^c(⋃n∈IAn)c=⋂n∈IAnc
# 3.	Intersección de una Familia de Conjuntos:
# o	La intersección de una familia de conjuntos {An}n∈I\{A_n\}_{n \in I}{An}n∈I es el conjunto de todos los elementos que están en todos los conjuntos AnA_nAn.
# o	Formalmente: ⋂n∈IAn={x∣∀n∈I tal que x∈An}\bigcap_{n \in I} A_n = \{ x \mid \forall n \in I \text{ tal que } x \in A_n \}⋂n∈IAn={x∣∀n∈I tal que x∈An}
# 4.	Complemento de una Intersección:
# o	El complemento de la intersección de una familia de conjuntos es el conjunto de todos los elementos que no están en la intersección.
# o	Formalmente: (⋂n∈IAn)c=⋃n∈IAnc {n \in I} A_^c A_n^c(⋂n∈IAn)c=⋃n∈IAnc
# Ejemplos
# 1.	Ejemplo de Unión:
# o	Sea An=(n,n+1)A_n = (n, n+1)An=(n,n+1) para n∈Zn \ n∈Z. La unión de estos intervalos cubre todo el conjunto de los números reales, es decir: ⋃n∈Z(n,n+1)=R (n, n+1) = R

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.	Ejemplo de Complemento de la Unión:
#
# o	Dado el mismo conjunto de intervalos An=(n,n+1)A_n = (n, n+1)An=(n,n+1) para, el complemento en los números reales es el conjunto de números enteros: (⋃n∈Z(n,n+1))c=Z{n \in (n, n+1)\^c = ((n,n+1))c=Z
#
#
#
#
#
#
#
#
# 3.	Ejemplo de Intersección:
#
# o	Sea An=(−n,n)A_n = (-n, n)An=(−n,n) para n∈N La intersección de estos conjuntos es el intervalo abierto que cubre todos los números reales: ⋂n∈N(−n,n)=R (-n, n) (−n,n)=R
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4.	Ejemplo de Complemento de la Intersección:
#
# o	Dado el conjunto An=(−n,n)A_n = (-n, n)An=(−n,n) para n∈Nn, el complemento de la intersección es el conjunto de todos los números reales fuera de este intervalo, es decir: (⋂n∈N(−n,n))c=∅ (-n, n)\right)^c =∅

# %%
import numpy as np

def generar_intervalos(n_max):
    """Genera intervalos abiertos de la forma (n, n+1) para n en el rango [-n_max, n_max]."""
    intervalos = [(n, n+1) for n in range(-n_max, n_max + 1)]
    return intervalos

def union_intervalos(intervalos):
    """Calcula la unión de una lista de intervalos abiertos."""
    puntos = []
    for inicio, fin in intervalos:
        puntos.append(inicio)
        puntos.append(fin)
    puntos = sorted(set(puntos))
    return (puntos[0], puntos[-1])

def complemento_union(union_intervalo):
    """Calcula el complemento de la unión en los números reales."""
    return "No hay complemento en los números reales porque la unión cubre todos los reales."

# Generar intervalos para n en [-5, 5]
n_max = 5
intervalos = generar_intervalos(n_max)

# Unión de intervalos
union = union_intervalos(intervalos)

# Mostrar la unión
print(f"Unión de los intervalos: {union}")

# Complemento de la unión en el conjunto de los números reales
complemento = complemento_union(union)
print(f"Complemento de la unión: {complemento}")
# Out:
# Unión de los intervalos: (-5, 6)
# Complemento de la unión: No hay complemento en los números reales porque la unión cubre todos los reales.

# %% [markdown]
# #**Funciones, Inyectividad, Sobreyectividad y Biyectividad**
#
# 1.	Función:
# o	Una función f:E→Ff: E Ff:E→F asigna un único valor en F a cada valor en E.
# 2.	Inyectividad:
# o	Una función f es inyectiva si diferentes elementos en E se mapean a diferentes elementos en F.
# o	Formalmente: f(x1)=f(x2)f(x_1) = f(x_2)f(x1)=f(x2) implica x1=x2x_1 = x_2x1=x2.
# Ejemplo:
# o	f(x)=2xf(x) = 2xf(x)=2x es inyectiva en {R}R porque si 2x1=2x22x_1 = 2x_22x1=2x2, entonces x1=x2x_1 = x_2x1=x2.

# %% [markdown]
# 3.	Sobreyectividad:
#
# Una función f es sobreyectiva si cada elemento en F es imagen de algún elemento en E.
# o	Formalmente: Para todo y∈Fy \in Fy∈F, existe x∈Ex \in Ex∈E tal que f(x)=yf(x) = yf(x)=y.
# Ejemplo:
# o	f(x)=x2f(x) = x^2f(x)=x2 mapeada de R\mathbb{R}R a [0,∞)[0, \infty)[0,∞) es sobreyectiva porque cada y≥0y \geq 0y≥0 tiene un x∈Rx \in \mathbb{R}x∈R tal que f(x)=yf(x) = yf(x)=y.

# %%
def f(x):
    return x**2

def es_sobreyectiva(func, dominio, codominio):
    imagen = {func(x) for x in dominio}
    return imagen >= codominio

dominio = range(-10, 11)
codominio = set(range(0, 101))
print(es_sobreyectiva(f, dominio, codominio))  # Debería ser True
# Out:
# False

# %% [markdown]
# 4.	Biyectividad:
#
# Una función f es biyectiva si es inyectiva y sobreyectiva.
# o	Formalmente: Cada elemento en f tiene un único antecedente en E.
# Ejemplo:
# o	f(x)=x+1f(x) = x + 1f(x)=x+1 es biyectiva porque es inyectiva (no mapea dos valores distintos a la misma imagen) y sobreyectiva (cubre todo R\ R).

# %%
def f(x):x + 1

def es_biyectiva(func, dominio, codominio):
    imagen = {func(x) for x in dominio}
    return imagen == codominio and len(imagen) == len(dominio)

dominio = range(0, 10)
codominio = set(range(1, 11))
print(es_biyectiva(f, dominio, codominio))  # Debería ser True
# Out:
# False

# %% [markdown]
# 1.	Espacio Métrico:
#
# Un espacio métrico es un conjunto EEE junto con una función de distancia d(x,y)d(x, y)d(x,y) que cumple tres propiedades:
#
# Positividad:
#
# d(x,y)≥0d(x, y) \geq 0d(x,y)≥0, y d(x,y)=0d(x, y) = 0d(x,y)=0 si y solo si x=yx = yx=y.
# o	Simetría: d(x,y)=d(y,x)d(x, y) = d(y, x)d(x,y)=d(y,x).
# o	Desigualdad Triangular: d(x,z)≤d(x,y)+d(y,z)d(x, z) \leq d(x, y) + d(y, z)d(x,z)≤d(x,y)+d(y,z).
#
#
# 2.	Punto Interior: Un punto x es interior a un conjunto A si existe una bola abierta alrededor de x que está completamente contenida en A.
#
# 3.	Punto de Frontera: Un punto x es un punto de frontera de A si cualquier bola alrededor de x intersecta tanto A como el complemento de A.
#
# 4.	Conjunto Abierto: Un conjunto A es abierto si cada punto de A es un punto interior de A.
#
# 5.	Conjunto Cerrado: Un conjunto A es cerrado si su complemento es abierto, o si contiene todos sus puntos de frontera.
#
# Ejemplos
#
# 1.	Ejemplo de Espacio Métrico:
#
# o	En R2 {R}^2R2, el espacio con la distancia euclidiana d((x1,y1),(x2,y2))=(x2−x1)2+(y2−y1)2d((x_1, y_1), (x_2, y_2)) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}d((x1,y1),(x2,y2))=(x2−x1)2+(y2−y1)2 es un espacio métrico.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.	Ejemplo de Punto Interior:
#
# o	En {R}R, el conjunto A=(1,3)A = (1, 3)A=(1,3) es abierto. Cualquier punto x dentro del intervalo (por ejemplo, x=2x = 2x=2) tiene una bola (en este caso, un intervalo abierto) alrededor de él que está completamente contenida en A.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.	Ejemplo de Punto de Frontera:
#
# o	En R, el punto 1 es un punto de frontera del conjunto A=[1,3)A = [1, 3)A=[1,3) porque cualquier intervalo alrededor de 1 intersecta tanto A como su complemento.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4.	Ejemplo de Conjunto Abierto:
#
# o	El conjunto A=(0,1)⊂RA = (0, 1) A=(0,1)⊂R es abierto porque para cualquier punto x∈(0,1)x \in (0, 1)x∈(0,1), puedes encontrar un intervalo alrededor de x que está contenido en A.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.	Ejemplo de Conjunto Cerrado:
#
# El conjunto A=[0,1]A = [0, 1]A=[0,1] es cerrado porque su complemento, (−∞,0)∪(1,∞)(−∞,0)∪(1,∞), es abierto, y A contiene todos sus puntos de frontera (0 y 1).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicio en Python 🔥
# A continuación, un ejercicio para calcular la distancia euclidiana entre dos puntos en un espacio de dos dimensiones:

# %%
import math

def distancia_euclidiana(punto1, punto2):
    """
    Calcula la distancia euclidiana entre dos puntos en un espacio 2D.

    Args:
    punto1 (tuple): Coordenadas del primer punto (x1, y1).
    punto2 (tuple): Coordenadas del segundo punto (x2, y2).

    Returns:
    float: Distancia euclidiana entre los dos puntos.
    """
    x1, y1 = punto1
    x2, y2 = punto2
    distancia = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return distancia

# Ejemplo de uso
punto_a = (3, 4)
punto_b = (7, 1)
print(f"La distancia euclidiana entre {punto_a} y {punto_b} es {distancia_euclidiana(punto_a, punto_b):.2f}")
# Out:
# La distancia euclidiana entre (3, 4) y (7, 1) es 5.00

# %% [markdown]
# Este código define una función para calcular la distancia euclidiana entre dos puntos en un plano bidimensional, usa la fórmula (x2−x1)2+(y2−y1)2\{(x_2 - x_1)^2 + (y_2 - y_1)^2}(x2−x1)2+(y2−y1)2, y proporciona un ejemplo de uso.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #CUESTIONARIO DE PREGUNTAS:📌📝
# Link del cuestionario de preguntas: https://quizizz.com/join?gc=89568109

# %%
# Primero, asegurémonos de que tenemos las bibliotecas necesarias
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols, Not, Or, And, Implies, Equivalent
from sympy.logic.boolalg import Or, And, Not

# Crear una función para visualizar los conjuntos y los intervalos
def plot_set_operations():
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    # Mostrar la intersección de conjuntos
    A = {1, 2, 3}
    B = {2, 3, 4}
    intersection = A & B
    ax[0].set_title('Intersección A ∩ B')
    ax[0].barh(['A ∩ B'], [len(intersection)], color='skyblue')
    ax[0].set_xlim(0, 4)
    ax[0].set_xlabel('Número de elementos')
    ax[0].set_yticks([])

    # Mostrar el complemento
    U = {1, 2, 3, 4, 5}
    A = {1, 2, 3}
    complement = U - A
    ax[1].set_title('Complemento de A en U')
    ax[1].barh(['U - A'], [len(complement)], color='salmon')
    ax[1].set_xlim(0, 4)
    ax[1].set_xlabel('Número de elementos')
    ax[1].set_yticks([])

    plt.show()

plot_set_operations()

# Pregunta 1: Proposición lógica
print("Pregunta 1: ¿Cuál de las siguientes es una proposición lógica?")
print("a) ¿Cuál es tu nombre?")
print("b) ¡Corre más rápido!")
print("c) La Tierra es redonda.")
print("d) ¡Qué día tan hermoso!")
print("e) ¿Podrías ayudarme?")
print("Respuesta Correcta: c) La Tierra es redonda.")
print("Explicación: Las proposiciones son declaraciones que pueden ser verdaderas o falsas. 'La Tierra es redonda' es una declaración que puede ser evaluada como verdadera o falsa.\n")

# Pregunta 2: Equivalencia de implicación
p, q = symbols('p q')
implication = Implies(p, q)
equiv = Equivalent(implication, Or(Not(p), q))
print("Pregunta 2: ¿Qué es equivalente a p→q?")
print("a) p∨q")
print("b) ¬p∨q")
print("c) ¬p∧q")
print("d) p∧¬q")
print("e) p↔q")
print(f"Respuesta Correcta: b) ¬p∨q")
print(f"Explicación: La implicación p→q es equivalente a ¬p∨q según la definición lógica.\n")

# Pregunta 3: Negación de conjunción
neg_conj = Not(And(p, q))
neg_conj_de_morgan = Or(Not(p), Not(q))
print("Pregunta 3: ¿Cuál es la negación de p∧q?")
print("a) ¬p∧q")
print("b) p∨q")
print("c) ¬p∨¬q")
print("d) ¬p∨q")
print("e) p∧¬q")
print(f"Respuesta Correcta: c) ¬p∨¬q")
print(f"Explicación: Según las leyes de De Morgan, la negación de p∧q es ¬p∨¬q.\n")

# Pregunta 4: Complemento de la unión de conjuntos
A, B = symbols('A B')
complement_union = And(Not(A), Not(B))
print("Pregunta 4: ¿Cuál es el complemento de A∪B?")
print("a) ¬A∩¬B")
print("b) ¬A∪B")
print("c) A∩B")
print("d) ¬(A∩B)")
print("e) A∪¬B")
print(f"Respuesta Correcta: a) ¬A∩¬B")
print(f"Explicación: Según la ley de De Morgan, el complemento de A∪B es ¬A∩¬B.\n")

# Pregunta 5: Intersección de conjuntos
A = {1, 2, 3}
B = {2, 3, 4}
intersection = A & B
print("Pregunta 5: ¿Qué elementos contiene A∩B si A={1,2,3} y B={2,3,4}?")
print("a) {1,2,3,4}")
print("b) {2,3}")
print("c) {1,4}")
print("d) {1,2}")
print("e) {3,4}")
print(f"Respuesta Correcta: b) {intersection}")
print(f"Explicación: La intersección A∩B contiene solo los elementos que están en ambos conjuntos A y B.\n")

# Pregunta 6: Complemento en el universo
U = {1, 2, 3, 4, 5}
A = {1, 2, 3}
complement = U - A
print("Pregunta 6: Si el universo es U={1,2,3,4,5} y A={1,2,3}, ¿cuál es el complemento de A?")
print("a) {1,2}")
print("b) {3,4}")
print("c) {4,5}")
print("d) {2,3,4}")
print("e) {1,2,3,4}")
print(f"Respuesta Correcta: c) {complement}")
print(f"Explicación: El complemento de A en el universo U son los elementos de U que no están en A.\n")

# Pregunta 7: Notación de intervalos cerrados
print("Pregunta 7: ¿Cuál es la notación correcta para un intervalo cerrado que incluye 2 y 5?")
print("a) (2,5)")
print("b) [2,5)")
print("c) (2,5]")
print("d) [2,5]")
print("e) (2,4)")
print("Respuesta Correcta: d) [2,5]")
print("Explicación: Un intervalo cerrado incluye ambos extremos, lo que se denota por corchetes.\n")

# Pregunta 8: Significado del intervalo (3,7)
print("Pregunta 8: ¿Qué significa el intervalo (3,7)?")
print("a) Incluye 3 y 7.")
print("b) Incluye 3 pero no 7.")
print("c) Incluye 7 pero no 3.")
print("d) No incluye 3 ni 7.")
print("e) Incluye 4 y 6.")
print("Respuesta Correcta: d) No incluye 3 ni 7.")
print("Explicación: Un intervalo abierto (3,7) no incluye los extremos 3 y 7.\n")

# Pregunta 9: Conjunto Z de enteros
print("Pregunta 9: ¿Cuál de los siguientes conjuntos representa Z?")
print("a) {1,2,3,…}")
print("b) {0,1,2,3,…}")
print("c) {…,−2,−1,0,1,2,…}")
print("d) {2,4,6,…}")
print("e) {3,6,9,…}")
print("Respuesta Correcta: c) {…,−2,−1,0,1,2,…}")
print("Explicación: Z incluye todos los enteros positivos, negativos y el cero.\n")

# Pregunta 10: Elemento neutro aditivo
print("Pregunta 10: ¿Cuál es el elemento neutro aditivo en los enteros?")
print("a) 1")
print("b) -1")
print("c) 0")
print("d) 2")
print("e) -2")
print("Respuesta Correcta: c) 0")
print("Explicación: El elemento neutro aditivo es aquel que, al sumarlo a cualquier entero, no cambia su valor. En este caso, es 0.\n")

# Pregunta 11: Propiedad de los enteros
print("Pregunta 11: ¿Cuál es la propiedad que garantiza que la suma de dos enteros siempre resulta en otro entero?")
print("a) Asociatividad")
print("b) Conmutatividad")
print("c) Cerradura")
print("d) Elemento neutro")
print("e) Inverso")
print("Respuesta Correcta: c) Cerradura")
print("Explicación: La propiedad de cerradura garantiza que la suma de dos enteros siempre resulta en otro entero.\n")

# Pregunta 12: Unión de intervalos
print("Pregunta 12: ¿Cuál es la unión de los conjuntos [1,2] y [2,3]?")
print("a) (1,3)")
print("b) [1,2]")
print("c) [1,3]")
print("d) [2,3]")
print("e) (2,3]")
print("Respuesta Correcta: c) [1,3]")
print("Explicación: La unión de [1,2] y [2,3] incluye todos los elementos en cualquiera de los dos intervalos, lo cual es [1,3].\n")
# Out:
# Pregunta 1: ¿Cuál de las siguientes es una proposición lógica?
# a) ¿Cuál es tu nombre?
# b) ¡Corre más rápido!
# c) La Tierra es redonda.
# d) ¡Qué día tan hermoso!
# e) ¿Podrías ayudarme?
# Respuesta Correcta: c) La Tierra es redonda.
# Explicación: Las proposiciones son declaraciones que pueden ser verdaderas o falsas. 'La Tierra es redonda' es una declaración que puede ser evaluada como verdadera o falsa.
#
# Pregunta 2: ¿Qué es equivalente a p→q?
# a) p∨q
# b) ¬p∨q
# c) ¬p∧q
# d) p∧¬q
# e) p↔q
# Respuesta Correcta: b) ¬p∨q
# Explicación: La implicación p→q es equivalente a ¬p∨q según la definición lógica.
#
# Pregunta 3: ¿Cuál es la negación de p∧q?
# a) ¬p∧q
# b) p∨q
# c) ¬p∨¬q
# d) ¬p∨q
# e) p∧¬q
# Respuesta Correcta: c) ¬p∨¬q
# Explicación: Según las leyes de De Morgan, la negación de p∧q es ¬p∨¬q.
#
# Pregunta 4: ¿Cuál es el complemento de A∪B?
# a) ¬A∩¬B
# b) ¬A∪B
# c) A∩B
# d) ¬(A∩B)
# e) A∪¬B
# Respuesta Correcta: a) ¬A∩¬B
# ...

# %% [markdown]
# ###©️ Referencias y Licencias
# Este trabajo utiliza material del curso "Matemáticas y Programación para Ciencias Sociales" de FLACSO Ecuador.
#
# Pérez, F. (2024). Matemáticas y Programación para Ciencias Sociales. FLACSO Ecuador.
#
# Repositorio GitHub: https://github.com/franperezec/math (Licencia MIT)
# Canal de YouTube: https://www.youtube.com/channel/UCAGEJb2ofN1E99dc-WbPkBQ (CC BY 4.0)
# Al utilizar este material, acepto cumplir con los términos de las licencias MIT y Creative Commons BY 4.0 respectivamente.
#
# Para más detalles sobre las licencias o usos adicionales, consultar:
#
# Licencia MIT: https://opensource.org/licenses/MIT
# CC BY 4.0: https://creativecommons.org/licenses/by/4.0/deed.es
